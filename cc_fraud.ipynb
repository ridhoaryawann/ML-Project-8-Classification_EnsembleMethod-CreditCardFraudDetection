# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **DataFrame Audit**

# %%
df = pd.read_csv("../creditcard_2023.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
print("There are no NaN Values")
df.isnull().sum()
# Out:
# There are no NaN Values
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print('There are no duplicate values')
df[df.duplicated()]
# Out:
# There are no duplicate values
# Empty DataFrame
# Columns: [id, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
print("Target seems to be balance")
df['Class'].value_counts()
# Out:
# Target seems to be balance
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486122  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %% [markdown]
# ### **Data Preparation**

# %%
# Feature Target Split
X = df.drop(['id','Class'], axis=1, errors='coerce')
y = df['Class']

X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0 -0.130006  0.727159  0.637735  ...  0.091202 -0.110552  0.217606 -0.134794
# 1 -0.133118  0.347452  0.529808  ... -0.233984 -0.194936 -0.605761  0.079469
# 2 -0.095576 -0.261297  0.690708  ...  0.361652 -0.005020  0.702906  0.945045
# 3 -0.065130 -0.205698  0.575231  ... -0.378223 -0.146927 -0.038212 -0.214048
# 4 -0.212660  1.049921  0.968046  ...  0.247237 -0.106984  0.729727 -0.161666
#
#         V24       V25       V26       V27       V28    Amount
# ...

# %%
# Train Test Split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (454904, 29) (454904,) (113726, 29) (113726,)

# %% [markdown]
# #### Make Pipeline for Data Transformation

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

col = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
       'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
       'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

prep = ColumnTransformer(
    transformers=[
    ('num', scaler, col)
     ],
     remainder = 'passthrough'
)

prep
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('num', StandardScaler(),
#                                  ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7',
#                                   'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14',
#                                   'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#                                   'V21', 'V22', 'V23', 'V24', 'V25', 'V26',
#                                   'V27', 'V28', 'Amount'])])

# %% [markdown]
# ### **Model Building**

# %% [markdown]
# ##### DT model

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(
    max_depth=5,
    min_samples_split=10,
    random_state=42
)

# %%
dt_model = Pipeline(
    [
        ('transformer',prep),
        ('dt',dt)
    ]
)

dt_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['V1', 'V2', 'V3', 'V4', 'V5',
#                                                    'V6', 'V7', 'V8', 'V9',
#                                                    'V10', 'V11', 'V12', 'V13',
#                                                    'V14', 'V15', 'V16', 'V17',
#                                                    'V18', 'V19', 'V20', 'V21',
#                                                    'V22', 'V23', 'V24', 'V25',
#                                                    'V26', 'V27', 'V28',
#                                                    'Amount'])])),
#                 ('dt',
#                  DecisionTreeClassifier(max_depth=5, min_samples_split=10,
#                                         random_state=42))])

# %% [markdown]
# ##### RF Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_split=5,
    random_state=42
)

# %%
rf_model = Pipeline(
    [
        ('transformer', prep),
        ('rf', rf)
    ]
)

rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['V1', 'V2', 'V3', 'V4', 'V5',
#                                                    'V6', 'V7', 'V8', 'V9',
#                                                    'V10', 'V11', 'V12', 'V13',
#                                                    'V14', 'V15', 'V16', 'V17',
#                                                    'V18', 'V19', 'V20', 'V21',
#                                                    'V22', 'V23', 'V24', 'V25',
#                                                    'V26', 'V27', 'V28',
#                                                    'Amount'])])),
#                 ('rf',
#                  RandomForestClassifier(max_depth=10, min_samples_split=5,
#                                         random_state=42))])

# %% [markdown]
# ### **Evaluation**

# %% [markdown]
# #### 1-Evaluation with cross validation
#     splitting data into separate piece to show how the model perform

# %%
from sklearn.model_selection import cross_val_score 

# dt 
cv_dt = cross_val_score(dt_model, X_train, y_train, cv=5, scoring='f1')
print(f"Avg CV score for decision tree {np.mean(cv_dt)} | {cv_dt}")
# Out:
# Avg CV score for decision tree 0.9598988223504111 | [0.95967742 0.96011211 0.95963152 0.96037859 0.95969447]

# %%
# rf
cv_rf = cross_val_score(rf_model, X_train, y_train, cv=5, scoring='f1')
print(f"Avg CV score for random forest : {np.mean(cv_rf)} | {cv_rf}")
# Out:
# Avg CV score for random forest : 0.9848135979171477 | [0.98470321 0.98644528 0.98474499 0.98431399 0.98386053]

# %% [markdown]
# #### 2-Evaluation with target
#     Predict using model and evaluate base on the result

# %%
y_pred_rf = rf_model.predict(X_test)

y_pred_dt = dt_model.predict(X_test)

# %% [markdown]
# ##### 2.A. Classification Report
#     shows almost all of the basic classification metrics (precision,recall,f1 score)

# %%
# rf clss report
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     56750
#            1       1.00      0.97      0.99     56976
#
#     accuracy                           0.99    113726
#    macro avg       0.99      0.99      0.99    113726
# weighted avg       0.99      0.99      0.99    113726

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     56750
#            1       0.97      0.95      0.96     56976
#
#     accuracy                           0.96    113726
#    macro avg       0.96      0.96      0.96    113726
# weighted avg       0.96      0.96      0.96    113726

# %% [markdown]
# ##### 2.B. Confusion Matrix
#     visualizing classification result of pred and real using Thrue-False-Pos-Neg Matrix

# %%
from sklearn.metrics import confusion_matrix

cm_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %%
cm_dt = confusion_matrix(y_test, y_pred_dt)
sns.heatmap(cm_dt, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted')

# %% [markdown]
# ##### 2.C. Feature Importance
#     See the importance features and evaluate each feature performance to predict

# %%
imp_rf = rf_model.named_steps['rf'].feature_importances_
imp_rf_df = pd.DataFrame({
    'Feature' : X.columns, 
    'Importance' : imp_rf
    }).sort_values('Importance',ascending=False)

imp_rf_df.head(5).plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ##### 2.D. Recheck Multicollinearity
#     visualizing multicoliearity of feature with the most importance prediction in predicting

# %%
sns.heatmap(X[['V10','V11','V13','V3','V9']].corr(), annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ##### 2.E. ROC / AUC
#
# **Show how model perform under many treshold** not only 0.5 like other matrix
#
# 1. ROC (Receiver Operating Characteristic) Curve shows how the true positive rate (recall) vs. false positive rate changes at every possible threshold.
#
# 2. AUC (Area Under the Curve) is a single number summarizing the model’s ability to separate classes, no matter what threshold you choose.

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

y_pred_prob         = rf_model.predict_proba(X_test)[:,1]
fpr, tpr, tresholds = roc_curve(y_test,y_pred_prob)
roc_auc             = auc(fpr, tpr)

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC Curve')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')  # diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})', color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with AUC')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
